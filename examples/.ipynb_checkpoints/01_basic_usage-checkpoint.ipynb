# %% [markdown]
# # 01 — Basic usage
#
# OGC API - Environmental Data Retrieval (EDR) is a query-API for
# environmental data (weather, ocean, climate, air quality). The 1.1 spec
# defines several query types — `edr-xarray` implements the `/cubes`
# query, which returns a regular grid as CoverageJSON.
#
# This notebook walks through the smallest possible workflow:
#
# 1. Spawn an in-process mock EDR server.
# 2. Open the collection as an `xarray.Dataset`.
# 3. Inspect dimensions, variables, coordinates, attributes.
# 4. Trigger a single lazy fetch by reading `.values`.
# 5. Shut everything down.
#
# No live server, no credentials, no external dependencies.

# %% [markdown]
# ## 1. Spawn the mock server
#
# The mock uses only the Python stdlib (`http.server`). It serves two
# endpoints:
#
# - `GET /collections/demo_collection` — collection metadata
# - `GET /collections/demo_collection/cube` — a 3D CoverageJSON grid

# %%
# Mock EDR server — Python stdlib only, no external dependencies.
import json
import threading
from http.server import BaseHTTPRequestHandler, HTTPServer


class _Handler(BaseHTTPRequestHandler):
    """Tiny request handler that serves a routing table of JSON payloads."""

    _routes: dict = {}

    def do_GET(self):  # noqa: N802  (BaseHTTPRequestHandler convention)
        path = self.path.split("?")[0]
        if path in self._routes:
            body = json.dumps(self._routes[path]).encode()
            self.send_response(200)
            self.send_header("Content-Type", "application/json")
            self.send_header("Content-Length", str(len(body)))
            self.end_headers()
            self.wfile.write(body)
        else:
            self.send_response(404)
            self.end_headers()

    def log_message(self, *args, **kwargs):
        # Silence the default stderr access log.
        pass


def _start_server(routes: dict) -> tuple:
    """Start the HTTP server in a daemon thread and return (server, base_url)."""
    _Handler._routes = routes
    srv = HTTPServer(("127.0.0.1", 0), _Handler)
    threading.Thread(target=srv.serve_forever, daemon=True).start()
    return srv, f"http://127.0.0.1:{srv.server_address[1]}"

# %%
def make_metadata(base_url: str, *, with_vertical: bool = False) -> dict:
    """Build a minimal valid OGC EDR collection metadata document."""
    extent = {
        "spatial": {
            "bbox": [[10.0, 40.0, 11.0, 41.0]],
            "crs": "http://www.opengis.net/def/crs/OGC/1.3/CRS84",
        },
        "temporal": {
            "interval": [[
                "2025-01-01T00:00:00Z",
                "2025-01-03T00:00:00Z",
            ]],
            "values": [
                "2025-01-01T00:00:00Z",
                "2025-01-02T00:00:00Z",
                "2025-01-03T00:00:00Z",
            ],
        },
    }
    if with_vertical:
        extent["vertical"] = {
            "interval": [[1000.0, 500.0]],
            "values": [1000.0, 850.0, 500.0],
            "vrs": "http://www.opengis.net/def/crs/EPSG/0/5714",
        }
    return {
        "id": "demo_collection",
        "title": "Demo Collection",
        "description": "Self-contained demo dataset for the edr-xarray notebook examples.",
        "crs": ["http://www.opengis.net/def/crs/OGC/1.3/CRS84"],
        "output_formats": ["CoverageJSON"],
        "extent": extent,
        "parameter_names": {
            "temperature": {
                "type": "Parameter",
                "unit": {
                    "label": {"en": "Kelvin"},
                    "symbol": {
                        "value": "K",
                        "type": "http://www.opengis.net/def/uom/UCUM/",
                    },
                },
                "observedProperty": {
                    "id": "http://vocab.nerc.ac.uk/standard_name/air_temperature/",
                    "label": {"en": "Air temperature"},
                },
            },
        },
        "data_queries": {
            "cube": {
                "link": {
                    "href": f"{base_url}/collections/demo_collection/cube",
                    "rel": "data",
                    "type": "application/prs.coverage+json",
                    "variables": {
                        "output_formats": ["CoverageJSON"],
                        "default_output_format": "CoverageJSON",
                        "crs_details": [{"crs": "CRS84", "wkt": ""}],
                    },
                }
            }
        },
    }

# %%
def make_coverage_3d() -> dict:
    """Return a 3D Grid CoverageJSON document with shape (t=3, y=3, x=3)."""
    return {
        "type": "Coverage",
        "domain": {
            "type": "Domain",
            "domainType": "Grid",
            "axes": {
                "x": {"values": [10.0, 10.5, 11.0]},
                "y": {"values": [40.0, 40.5, 41.0]},
                "t": {"values": [
                    "2025-01-01T00:00:00Z",
                    "2025-01-02T00:00:00Z",
                    "2025-01-03T00:00:00Z",
                ]},
            },
            "referencing": [
                {
                    "coordinates": ["x", "y"],
                    "system": {
                        "type": "GeographicCRS",
                        "id": "http://www.opengis.net/def/crs/OGC/1.3/CRS84",
                    },
                },
                {
                    "coordinates": ["t"],
                    "system": {"type": "TemporalRS", "calendar": "Gregorian"},
                },
            ],
        },
        "parameters": {
            "temperature": {
                "type": "Parameter",
                "unit": {
                    "label": {"en": "Kelvin"},
                    "symbol": {
                        "value": "K",
                        "type": "http://www.opengis.net/def/uom/UCUM/",
                    },
                },
                "observedProperty": {
                    "id": "http://vocab.nerc.ac.uk/standard_name/air_temperature/",
                    "label": {"en": "Air temperature"},
                },
            },
        },
        "ranges": {
            "temperature": {
                "type": "NdArray",
                "dataType": "float",
                "axisNames": ["t", "y", "x"],
                "shape": [3, 3, 3],
                "values": [
                    273.15, 274.0, 275.0, 276.0, 277.0, 278.0, 279.0, 280.0, 281.0,
                    272.0, 273.0, 274.0, 275.0, 276.0, 277.0, 278.0, 279.0, 280.0,
                    271.0, 272.0, 273.0, 274.0, 275.0, 276.0, 277.0, 278.0, 279.0,
                ],
            },
        },
    }

# %%
# Start the server with an empty routes dict, then patch in the routes
# now that we know the port.
routes: dict = {}
srv, base_url = _start_server(routes)
routes["/collections/demo_collection"] = make_metadata(base_url)
routes["/collections/demo_collection/cube"] = make_coverage_3d()
print(f"mock server listening at {base_url}")

# %% [markdown]
# ## 2. Open the collection
#
# `edr-xarray` registers itself as the `"edr"` xarray engine when imported.
# Pointing `xr.open_dataset` at a `/collections/{id}` URL with
# `engine="edr"` is all it takes.

# %%
import xarray as xr

import edr_xarray  # registers engine="edr"

ds = xr.open_dataset(
    f"{base_url}/collections/demo_collection",
    engine="edr",
)
ds

# %% [markdown]
# ## 3. Inspect structure (no fetch)
#
# At this point the library has issued **at most two requests**: one for
# the collection metadata, plus an optional probe of the cube endpoint to
# discover grid axes. No actual data values have been transferred yet.

# %%
print("dims:       ", dict(ds.dims))
print("data_vars:  ", list(ds.data_vars))
print("coords:     ", list(ds.coords))
print("attrs:      ", dict(ds.attrs))
print()
print("temperature attrs:")
for k, v in ds["temperature"].attrs.items():
    print(f"  {k}: {v}")

# %% [markdown]
# ## 4. Lazy load values
#
# Calling `.values` (or `.load()`, `.compute()`) on a `DataArray` triggers
# a single GET against the cube endpoint. With no slicing, the full grid
# is requested.

# %%
arr = ds["temperature"].values
print("shape:", arr.shape)
print("dtype:", arr.dtype)
print()
print("first time slice (y=3, x=3):")
print(arr[0])

# %% [markdown]
# ## 5. Cleanup
#
# Always close the dataset (releases the underlying `httpx.Client`) and
# shut down the mock server when you are done.

# %%
ds.close()
srv.shutdown()
print("server stopped")
