# %% [markdown]
# # 02 — Subsetting
#
# `edr-xarray` exposes four "open-time" subset filters that the EDR
# server applies to every fetch issued by the resulting dataset:
#
# | Parameter | Maps to EDR query param | Example |
# |---|---|---|
# | `bbox=(lon_min, lat_min, lon_max, lat_max)` | `bbox` | spatial subset |
# | `datetime="..."` | `datetime` | instant or `start/end` interval |
# | `z=850` or `z="1000/500"` | `z` | vertical level / range |
# | `parameter_names=[...]` | filters which variables appear in the dataset | |
#
# This notebook demonstrates each in turn against a 4D mock cube
# (`t × z × y × x`).
#
# **Note**: the mock server does *not* actually filter responses — it
# just serves the same payload regardless of query parameters. In a real
# EDR deployment the server returns a smaller subset. The point of this
# notebook is to show how to *request* the subsets with the public API.

# %% [markdown]
# ## Setup
#
# We reuse the same `_start_server` helper, but ask `make_metadata` to
# include a `vertical` extent so the metadata is consistent with our 4D
# cube response.

# %%
# Mock EDR server — Python stdlib only, no external dependencies.
import json
import threading
from http.server import BaseHTTPRequestHandler, HTTPServer


class _Handler(BaseHTTPRequestHandler):
    """Tiny request handler that serves a routing table of JSON payloads."""

    _routes: dict = {}

    def do_GET(self):  # noqa: N802  (BaseHTTPRequestHandler convention)
        path = self.path.split("?")[0]
        if path in self._routes:
            body = json.dumps(self._routes[path]).encode()
            self.send_response(200)
            self.send_header("Content-Type", "application/json")
            self.send_header("Content-Length", str(len(body)))
            self.end_headers()
            self.wfile.write(body)
        else:
            self.send_response(404)
            self.end_headers()

    def log_message(self, *args, **kwargs):
        # Silence the default stderr access log.
        pass


def _start_server(routes: dict) -> tuple:
    """Start the HTTP server in a daemon thread and return (server, base_url)."""
    _Handler._routes = routes
    srv = HTTPServer(("127.0.0.1", 0), _Handler)
    threading.Thread(target=srv.serve_forever, daemon=True).start()
    return srv, f"http://127.0.0.1:{srv.server_address[1]}"

# %%
def make_metadata(base_url: str, *, with_vertical: bool = False) -> dict:
    """Build a minimal valid OGC EDR collection metadata document."""
    extent = {
        "spatial": {
            "bbox": [[10.0, 40.0, 11.0, 41.0]],
            "crs": "http://www.opengis.net/def/crs/OGC/1.3/CRS84",
        },
        "temporal": {
            "interval": [[
                "2025-01-01T00:00:00Z",
                "2025-01-03T00:00:00Z",
            ]],
            "values": [
                "2025-01-01T00:00:00Z",
                "2025-01-02T00:00:00Z",
                "2025-01-03T00:00:00Z",
            ],
        },
    }
    if with_vertical:
        extent["vertical"] = {
            "interval": [[1000.0, 500.0]],
            "values": [1000.0, 850.0, 500.0],
            "vrs": "http://www.opengis.net/def/crs/EPSG/0/5714",
        }
    return {
        "id": "demo_collection",
        "title": "Demo Collection",
        "description": "Self-contained demo dataset for the edr-xarray notebook examples.",
        "crs": ["http://www.opengis.net/def/crs/OGC/1.3/CRS84"],
        "output_formats": ["CoverageJSON"],
        "extent": extent,
        "parameter_names": {
            "temperature": {
                "type": "Parameter",
                "unit": {
                    "label": {"en": "Kelvin"},
                    "symbol": {
                        "value": "K",
                        "type": "http://www.opengis.net/def/uom/UCUM/",
                    },
                },
                "observedProperty": {
                    "id": "http://vocab.nerc.ac.uk/standard_name/air_temperature/",
                    "label": {"en": "Air temperature"},
                },
            },
        },
        "data_queries": {
            "cube": {
                "link": {
                    "href": f"{base_url}/collections/demo_collection/cube",
                    "rel": "data",
                    "type": "application/prs.coverage+json",
                    "variables": {
                        "output_formats": ["CoverageJSON"],
                        "default_output_format": "CoverageJSON",
                        "crs_details": [{"crs": "CRS84", "wkt": ""}],
                    },
                }
            }
        },
    }

# %%
def make_coverage_4d() -> dict:
    """Return a 4D Grid CoverageJSON with shape (t=3, z=3, y=3, x=3)."""
    # 3 * 3 * 3 * 3 = 81 values; deterministic synthetic data.
    values = [273.15 + 0.1 * i for i in range(81)]
    return {
        "type": "Coverage",
        "domain": {
            "type": "Domain",
            "domainType": "Grid",
            "axes": {
                "x": {"values": [10.0, 10.5, 11.0]},
                "y": {"values": [40.0, 40.5, 41.0]},
                "z": {"values": [1000.0, 850.0, 500.0]},
                "t": {"values": [
                    "2025-01-01T00:00:00Z",
                    "2025-01-02T00:00:00Z",
                    "2025-01-03T00:00:00Z",
                ]},
            },
            "referencing": [
                {
                    "coordinates": ["x", "y"],
                    "system": {
                        "type": "GeographicCRS",
                        "id": "http://www.opengis.net/def/crs/OGC/1.3/CRS84",
                    },
                },
                {
                    "coordinates": ["z"],
                    "system": {
                        "type": "VerticalCRS",
                        "id": "http://www.opengis.net/def/crs/EPSG/0/5714",
                    },
                },
                {
                    "coordinates": ["t"],
                    "system": {"type": "TemporalRS", "calendar": "Gregorian"},
                },
            ],
        },
        "parameters": {
            "temperature": {
                "type": "Parameter",
                "unit": {
                    "label": {"en": "Kelvin"},
                    "symbol": {
                        "value": "K",
                        "type": "http://www.opengis.net/def/uom/UCUM/",
                    },
                },
                "observedProperty": {
                    "id": "http://vocab.nerc.ac.uk/standard_name/air_temperature/",
                    "label": {"en": "Air temperature"},
                },
            },
        },
        "ranges": {
            "temperature": {
                "type": "NdArray",
                "dataType": "float",
                "axisNames": ["t", "z", "y", "x"],
                "shape": [3, 3, 3, 3],
                "values": values,
            },
        },
    }

# %%
routes: dict = {}
srv, base_url = _start_server(routes)
routes["/collections/demo_collection"] = make_metadata(
    base_url, with_vertical=True,
)
routes["/collections/demo_collection/cube"] = make_coverage_4d()
collection_url = f"{base_url}/collections/demo_collection"

import xarray as xr
import edr_xarray  # noqa: F401  (engine registration side-effect)

print(f"mock server: {base_url}")

# %% [markdown]
# ## Spatial subset — `bbox`
#
# Pass a CRS84 bounding box as `(lon_min, lat_min, lon_max, lat_max)`.
# The bbox is included in *every* fetch the dataset performs, so a
# spatial subset combined with a temporal subset just adds both query
# parameters together.

# %%
ds_spatial = xr.open_dataset(
    collection_url,
    engine="edr",
    bbox=(10.0, 40.0, 10.5, 40.5),
)
print("dims with bbox:", dict(ds_spatial.dims))
ds_spatial.close()

# %% [markdown]
# ## Temporal subset — `datetime`
#
# `datetime` accepts either a single ISO 8601 instant or a `start/end`
# interval. Open intervals (`..`) are not supported in v1.

# %%
# Single instant
ds_instant = xr.open_dataset(
    collection_url,
    engine="edr",
    datetime="2025-01-02T00:00:00Z",
)
print("instant:", dict(ds_instant.dims))
ds_instant.close()

# Closed interval
ds_interval = xr.open_dataset(
    collection_url,
    engine="edr",
    datetime="2025-01-01T00:00:00Z/2025-01-02T00:00:00Z",
)
print("interval:", dict(ds_interval.dims))
ds_interval.close()

# %% [markdown]
# ## Vertical subset — `z`
#
# `z` accepts a scalar (single level) or a `lo/hi` string (range).

# %%
ds_level = xr.open_dataset(collection_url, engine="edr", z=850)
print("single level z=850:", dict(ds_level.dims))
ds_level.close()

ds_z_range = xr.open_dataset(collection_url, engine="edr", z="1000/500")
print("range z=1000/500:", dict(ds_z_range.dims))
ds_z_range.close()

# %% [markdown]
# ## Parameter selection — `parameter_names`
#
# When set, only the listed variables appear as `data_vars` on the
# resulting dataset. This is a client-side filter on the metadata and is
# useful when a collection advertises dozens of parameters but you only
# want a handful.

# %%
ds_one_var = xr.open_dataset(
    collection_url,
    engine="edr",
    parameter_names=["temperature"],
)
print("data_vars:", list(ds_one_var.data_vars))
ds_one_var.close()

# %% [markdown]
# ## Combine
#
# All four subsets compose freely.

# %%
ds_combo = xr.open_dataset(
    collection_url,
    engine="edr",
    bbox=(10.0, 40.0, 10.5, 40.5),
    datetime="2025-01-01T00:00:00Z/2025-01-02T00:00:00Z",
    z=850,
    parameter_names=["temperature"],
)
print("combined dims:", dict(ds_combo.dims))
print("combined vars:", list(ds_combo.data_vars))
ds_combo.close()

# %% [markdown]
# ## Cleanup

# %%
srv.shutdown()
print("server stopped")
